# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("sales_train.csv")
categories = pd.read_csv("items.csv")

# %%
df = pd.merge(dataset, categories)

# %%
df = df.drop(['item_name'],axis = 1)

# %%
df.head(10)
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0  02.01.2013               0       59    22154       999.0           1.0
# 1  23.01.2013               0       24    22154       999.0           1.0
# 2  20.01.2013               0       27    22154       999.0           1.0
# 3  02.01.2013               0       25    22154       999.0           1.0
# 4  03.01.2013               0       25    22154       999.0           1.0
# 5  20.01.2013               0       25    22154       999.0           1.0
# 6  23.01.2013               0       25    22154       999.0           1.0
# 7  26.01.2013               0       25    22154       999.0           1.0
# 8  27.01.2013               0        6    22154       999.0           1.0
# 9  10.01.2013               0       15    22154       999.0           1.0
#
#    item_category_id
# 0                37
# 1                37
# 2                37
# 3                37
# 4                37
# 5                37
# ...

# %%
df.describe()
# Out:
#        date_block_num       shop_id       item_id    item_price  item_cnt_day  \
# count    2.935849e+06  2.935849e+06  2.935849e+06  2.935849e+06  2.935849e+06
# mean     1.456991e+01  3.300173e+01  1.019723e+04  8.908532e+02  1.242641e+00
# std      9.422988e+00  1.622697e+01  6.324297e+03  1.729800e+03  2.618834e+00
# min      0.000000e+00  0.000000e+00  0.000000e+00 -1.000000e+00 -2.200000e+01
# 25%      7.000000e+00  2.200000e+01  4.476000e+03  2.490000e+02  1.000000e+00
# 50%      1.400000e+01  3.100000e+01  9.343000e+03  3.990000e+02  1.000000e+00
# 75%      2.300000e+01  4.700000e+01  1.568400e+04  9.990000e+02  1.000000e+00
# max      3.300000e+01  5.900000e+01  2.216900e+04  3.079800e+05  2.169000e+03
#
#        item_category_id
# count      2.935849e+06
# mean       4.000138e+01
# std        1.710076e+01
# min        0.000000e+00
# 25%        2.800000e+01
# 50%        4.000000e+01
# 75%        5.500000e+01
# max        8.300000e+01

# %%
df.groupby(['date_block_num']).agg(['count', 'size', 'nunique']).stack()
# Out:
#                           date  shop_id  item_id  item_price  item_cnt_day  \
# date_block_num
# 0              count    115690   115690   115690      115690        115690
#                size     115690   115690   115690      115690        115690
#                nunique      31       45     8115        1945            33
# 1              count    108613   108613   108613      108613        108613
#                size     108613   108613   108613      108613        108613
#                nunique      28       46     8168        1962            36
# 2              count    121347   121347   121347      121347        121347
#                size     121347   121347   121347      121347        121347
#                nunique      31       46     8302        1907            48
# 3              count     94109    94109    94109       94109         94109
#                size      94109    94109    94109       94109         94109
# ...

# %%
df.corr()
# Out:
#                   date_block_num   shop_id   item_id  item_price  \
# date_block_num          1.000000  0.019273  0.009356    0.095010
# shop_id                 0.019273  1.000000  0.029396   -0.024034
# item_id                 0.009356  0.029396  1.000000   -0.134104
# item_price              0.095010 -0.024034 -0.134104    1.000000
# item_cnt_day            0.009402 -0.005230  0.016650    0.011197
# item_category_id        0.029128  0.019380  0.369431   -0.253554
#
#                   item_cnt_day  item_category_id
# date_block_num        0.009402          0.029128
# shop_id              -0.005230          0.019380
# item_id               0.016650          0.369431
# item_price            0.011197         -0.253554
# item_cnt_day          1.000000          0.014768
# item_category_id      0.014768          1.000000

# %%
sns.heatmap(df.corr())

# %%
dateList = pd.to_datetime(df['date'])

# %%
df['date'] = dateList
df = df.sort_values(by='date',ascending=True)
df = df.set_index('date')

# %%
sns.set(rc={'figure.figsize':(20, 4)})
df['item_cnt_day'].plot(linewidth=0.5)
